# %%
import pandas as pd
data = pd.read_csv('cran.all', sep="\t", header=None,index_col=0)

# %%
from nltk.tokenize import MWETokenizer
tokenizer = MWETokenizer()
tokenizer.tokenize(data.to_string())
# Out:
# ['E',
#  'm',
#  'p',
#  't',
#  'y',
#  ' ',
#  'D',
#  'a',
#  't',
#  'a',
#  'F',
#  'r',
#  'a',
#  'm',
#  'e',
#  '\n',
#  'C',
#  'o',
#  'l',
#  'u',
#  'm',
#  'n',
#  's',
#  ':',
#  ' ',
#  '[',
#  ']',
#  '\n',
#  'I',
#  'n',
#  'd',
#  'e',
#  'x',
#  ':',
#  ' ',
#  '[',
#  '.',
#  'I',
#  ' ',
#  '1',
#  ',',
#  ' ',
#  '.',
#  'T',
#  ',',
#  ' ',
#  'e',
#  'x',
#  'p',
#  'e',
#  'r',
#  'i',
#  'm',
#  'e',
#  'n',
#  't',
#  'a',
#  'l',
#  ' ',
#  'i',
#  'n',
#  'v',
#  'e',
#  's',
#  't',
#  'i',
#  'g',
#  'a',
#  't',
#  'i',
#  'o',
#  'n',
#  ' ',
#  'o',
#  'f',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  'a',
#  'e',
#  'r',
#  'o',
#  'd',
#  'y',
#  'n',
#  'a',
#  'm',
#  'i',
#  'c',
#  's',
#  ' ',
#  'o',
#  'f',
#  ' ',
#  'a',
#  ',',
#  ' ',
#  'w',
#  'i',
#  'n',
#  'g',
#  ' ',
#  'i',
#  'n',
#  ' ',
#  'a',
#  ' ',
#  's',
#  'l',
#  'i',
#  'p',
#  's',
#  't',
#  'r',
#  'e',
#  'a',
#  'm',
#  ' ',
#  '.',
#  ',',
#  ' ',
#  '.',
# ...
