# %%
import numpy as np
import math
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

# fig,ax=plt.subplots(figsize=(5, 5))
# ax.set_xlabel('inputs')
# ax.set_ylabel('outputs')

# x=np.array([0,1,2,3])
# y=np.array([1,2,3,4])
# output=plt.plot([x,y],label="Output")

# x=np.array([0,1,2,3])
# y=np.array([2,4,6,8])
# expected =plt.plot([x,y],label="Expected")
# plt.legend(handles=[output,expected])
# for i in range(4):
#     print(math.tan(i)*x+10)

# %%
from scipy import interpolate
x =np.linspace(-4, 4)
fig, ax = plt.subplots(figsize=(5, 5))
ax.plot(x,x**2,'--r', label='Error Square')
# ax.axis('equal')
leg = ax.legend(['Error Square', 'Cubic Spline', 'True']);

# %%
# from scipy import interpolate
# x=np.array([0,1,2,3])
# fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
# ax[0].plot(x,x*1+1, '-b', label='Output')
# ax[0].plot(x,x*2+2, '--r', label='Expected')
# # ax.axis('equal')
# leg = ax[0].legend();

# x =np.linspace(0, 3)
# # fig, ax = plt.subplots(figsize=(5, 5))
# ax[1].plot(x,(x+1)**2,'--r', label='Error Square')
# # ax.axis('equal')
# leg = ax[1].legend(['Error Square', 'Cubic Spline', 'True']);
