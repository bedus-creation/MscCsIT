# %%
import pandas as pd
import csv
users = pd.read_csv('users.csv',quotechar='"',
            sep=",",
            header=None,
            escapechar="\\",
            quoting=csv.QUOTE_ALL,
            error_bad_lines=False,
            encoding="utf-8")
users.head()
# Out:
#    0                                                  1         2   \
# 0  16                 Websoft International/Asianart.com  asianart
# 1  17                              WebSoft International       wsi
# 2  24              IUCN ( The World Conservation Union )      iucn
# 3  26  Gulmi Arghakhanchi Rural Development Project P...     gardp
# 4  27               Canada-Nepal Gender in Organizations      cngo
#
#                        3                        4   5   \
# 0  ian.alsop@asianart.com                 554 7709 NaN
# 1    jobs@websoftintl.com  01-5547709 / 01-5547710 NaN
# 2          hr@iucn.org.np                      01- NaN
# 3          psu@mos.com.np             977-1-526207 NaN
# 4         cngo@cco.org.np                       01 NaN
#
#                                                   6   7                    8   \
# 0  $2b$10$09Q60aR6xjRGX/TEjmDzheDLyyUnIaYrk67xbIs... NaN  2019-12-07 02:15:04
# ...

# %%
import pandas as pd
import csv
resumelogin = pd.read_csv('resumelogin.csv',quotechar='"',
            sep=";",
            header=None,
            escapechar="\\",
            quoting=csv.QUOTE_ALL,
            error_bad_lines=False,
            encoding="utf-8")
resumelogin.head()
# Out:
#    0            1         2                        3    4   5   6   \
# 0  27          ian  hicelapi  ianalsop108@hotmail.com  NaN   2  Mr
# 1  29        skshr    525047         fvc@wlink.com.np  NaN   1  Mr
# 2  31         naps  giwidaci      npd355@netscape.net  NaN   0  Mr
# 3  32  s69tuladhar   rumours   sameer@websoftintl.com  NaN   1  Mr
# 4  34         Puru  sayocira  purupradhan@hotmail.com  NaN   0  Mr
#
#                7         8           9   ...              19   20  \
# 0             Ian     Alsop  1947-07-28  ...  1 413 215 5670  NaN
# 1           Sanam  Shrestha  1969-06-07  ...             NaN  NaN
# 2  Narayan Prasad     Duwal  1976-12-10  ...             NaN  NaN
# 3          Sameer  Tuladhar  1900-01-01  ...             NaN  NaN
# 4     Purushottam   Pradhan  1900-01-01  ...             NaN  NaN
#
#                          21          22 23 24          25          26  \
# 0  https://www.themete.com/  2000-08-11  0  0  0000-00-00  0000-00-00
# ...
